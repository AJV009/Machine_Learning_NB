# %%
using JuliaAcademyData; activate("Foundations of machine learning")
# Out:
#  Activating environment at `C:\Users\XeonAJ\.julia\packages\JuliaAcademyData\1to3l\courses\Foundations of machine learning\Project.toml`

# %%
include(datapath("scripts/draw_neural_net.jl"))

num_in, num_neurons = 4, 1

draw_network([num_in, num_neurons])

# %%
draw_network([2,1])

# %%
using LinearAlgebra

# %%
# \cdot ->
sig(x) = 1 / (1 + exp(-x))
f(x,w,b) = sig(dot(w,x+b))
# Out:
# f (generic function with 1 method)

# %%
# Out:
# TypeError: non-boolean (Float64) used in boolean context
#
# Stacktrace:
#  [1] top-level scope at In[13]:1
